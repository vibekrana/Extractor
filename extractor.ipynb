# %%
pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
# ...

# %%
#importing chrome webdriver
from selenium import webdriver

# %%
#it will open the browser for the given url
dr = webdriver.Chrome()

# %%
# for opening a website we use .get function
# dr.get("https://amazon.in")

# %%
websites = [
    "https://www.selenium.dev/documentation/webdriver/",
    "https://www.browserstack.com/guide/selenium-webdriver-tutorial",
    "https://www.guru99.com/selenium-tutorial.html",
    "https://codoid.com/selenium-webdriver-tutorial/",
    "https://www.lambdatest.com/blog/selenium-webdriver-tutorial/",
    "https://www.toolsqa.com/selenium-webdriver/",
    "https://testgrid.io/blog/selenium-webdriver-tutorial/",
    "https://www.softwaretestinghelp.com/selenium-tutorial/",
    "https://www.edureka.co/blog/selenium-tutorial/",
    "https://dzone.com/automation-testing",
    "https://www.geeksforgeeks.org/selenium-python-tutorial/",
    "https://realpython.com/selenium-python-beginner/",
    "https://www.browserstack.com/docs/automate/selenium",
    "https://www.qaautomated.com/selenium-tutorial",
    "https://www.selenium.dev/blog/",
    "https://www.tutorialspoint.com/selenium/index.htm",
    "https://www.javatpoint.com/selenium-tutorial",
    "https://testautomationu.applitools.com/",
    "https://selenium-python.readthedocs.io/",
    "https://www.w3schools.io/tools/selenium/",
    "https://www.testim.io/blog/selenium-webdriver/",
    "https://www.tutorialspoint.com/selenium_webdriver/index.htm",
    "https://www.toptal.com/selenium/test-automation-in-python-using-selenium",
    "https://www.swtestacademy.com/selenium-webdriver/",
    "https://medium.com/swlh/selenium-webdriver-tutorial",
    "https://www.guru99.com/selenium-python.html",
    "https://pythonbasics.org/selenium/",
    "https://www.programiz.com/python-programming/web-scraping/selenium",
    "https://www.scrapingbee.com/blog/selenium-python/",
    "https://intellipaat.com/blog/tutorial/python-tutorial/selenium-with-python/",
    "https://pypi.org/project/selenium/",
    "https://www.linkedin.com/learning/learning-selenium",
    "https://testproject.io/blog/selenium-webdriver/",
    "https://www.lambdatest.com/blog/selenium-python-tutorial/",
    "https://www.selenium.dev/downloads/",
    "https://www.datacamp.com/community/tutorials/selenium-web-scraping-python",
    "https://www.ranorex.com/blog/selenium-webdriver-quick-start-guide/",
    "https://www.pluralsight.com/courses/selenium-automation-testing",
    "https://www.selenium.dev/selenium/docs/api/py/",
    "https://www.mygreatlearning.com/blog/selenium-python-tutorial/",
    "https://www.educba.com/selenium-python/",
    "https://testguild.com/",
    "https://github.com/SeleniumHQ/selenium",
    "https://www.scrapehero.com/how-to-use-selenium-with-python/",
    "https://levelup.gitconnected.com/selenium-python-guide-7fc20863b8f7",
    "https://crossbrowsertesting.com/resources/tutorials/selenium-webdriver-tutorial/",
    "https://dev.to/topic/selenium",
    "https://www.browserstack.com/local-testing/selenium",
    "https://testbytes.net/blog/selenium-tutorial/",
    "https://www.quora.com/What-are-the-best-tutorials-for-Selenium-WebDriver"
]

# %%
import time

# %%
for i in websites:
    dr.get(i)
    time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File c:\ProgramData\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# ...
